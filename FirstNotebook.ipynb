# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
mostFollowed = pd.read_csv('/content/drive/MyDrive/DataSets/MostFollowed.csv', encoding= 'ISO-8859-1')

# %%
mostFollowed.head()
# Out:
#    Rank      Username              Owner Brand\naccount  \
# 0     1    @instagram          Instagram              +
# 1     2    @cristiano  Cristiano Ronaldo              -
# 2     3     @leomessi       Lionel Messi              -
# 3     4  @kyliejenner       Kylie Jenner              -
# 4     5  @selenagomez       Selena Gomez              -
#
#    Followers(millions)[2]                              Profession/Activity  \
# 0                   583.0                            Social media platform
# 1                   525.0                                       Footballer
# 2                   411.0                                       Footballer
# 3                   376.0  Television personality, model and businesswoman
# 4                   366.0             Musician, actress, and businesswoman
#
#   Country/Continent
# 0     United States
# 1          Portugal
# 2         Argentina
# 3     United States
# 4     United States

# %%
mostFollowed.set_index('Rank')

# %%
mostFollowed.columns = ['Rank', 'Usuário', 'Proprietário', 'Marca', 'Seguidores', 'Categoria', 'País']
mostFollowed.set_index('Rank').head()
mostFollowed.drop(columns = ['Usuário', 'Marca'])
# Out:
#     Rank           Proprietário  Seguidores  \
# 0      1              Instagram       583.0
# 1      2      Cristiano Ronaldo       525.0
# 2      3           Lionel Messi       411.0
# 3      4           Kylie Jenner       376.0
# 4      5           Selena Gomez       366.0
# 5      6         Dwayne Johnson       355.0
# 6      7          Ariana Grande       346.0
# 7      8         Kim Kardashian       337.0
# 8      9                Beyoncé       288.0
# 9     10       Khloé Kardashian       285.0
# 10    11          Justin Bieber       271.0
# 11    12         Kendall Jenner       268.0
# 12    13                   Nike       259.0
# 13    14    National Geographic       252.0
# 14    15           Taylor Swift       237.0
# 15    16         Jennifer Lopez       230.0
# 16    17            Virat Kohli       229.0
# 17    18            Nicki Minaj       207.0
# 18    19    Kourtney Kardashian       206.0
# 19    20                 Neymar       198.0
# ...

# %%
grafico = mostFollowed.groupby(['País']).size().sort_values().plot(title='Países mais influentes no Top 50 do Instagram',kind = 'barh').set(xlabel='Quantidade de usuários influentes no Top 50')
